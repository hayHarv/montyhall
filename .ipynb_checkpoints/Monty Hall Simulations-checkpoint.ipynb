# %%
% matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
import real_monty as rm

# %%
three_doors = {}
five_doors = {}
num_doors = [3,5,10,50,100]
doors = {}
for i in num_doors:
    t = rm.N_trials(n=10000, n_doors = i)
    t.run_trials()
    doors[i] = t.outcome_proba

# %%
n_trials = list(range(10, 10000, 100))
ten_door_switch = []
ten_door_stay = []
for i in n_trials:
    t = rm.N_trials(n=i, n_doors = 10)
    t.run_trials()
    print(i)
    ten_door_switch.append(t.outcome_proba['switch'])
    ten_door_stay.append(t.outcome_proba['stay'])
# Out:
# 10
# 110
# 210
# 310
# 410
# 510
# 610
# 710
# 810
# 910
# 1010
# 1110
# 1210
# 1310
# 1410
# 1510
# 1610
# 1710
# 1810
# 1910
# 2010
# 2110
# 2210
# 2310
# 2410
# 2510
# 2610
# 2710
# 2810
# 2910
# 3010
# 3110
# 3210
# 3310
# 3410
# 3510
# 3610
# 3710
# 3810
# 3910
# 4010
# 4110
# 4210
# 4310
# 4410
# 4510
# 4610
# 4710
# 4810
# 4910
# 5010
# 5110
# 5210
# 5310
# 5410
# 5510
# 5610
# 5710
# 5810
# 5910
# 6010
# 6110
# 6210
# 6310
# 6410
# 6510
# 6610
# 6710
# 6810
# 6910
# 7010
# 7110
# 7210
# 7310
# 7410
# 7510
# 7610
# 7710
# 7810
# 7910
# 8010
# 8110
# 8210
# 8310
# 8410
# 8510
# 8610
# 8710
# 8810
# 8910
# 9010
# 9110
# 9210
# 9310
# 9410
# 9510
# 9610
# 9710
# 9810
# 9910

# %%
fig = plt.figure(figsize=(10,6))
ax = fig.add_subplot(111)
ax.plot(n_trials, ten_door_stay, 'r')
ax.plot(n_trials, ten_door_switch, 'b')
plt.show()

# %%
import numpy as np

# %%
np.average(ten_door_stay)
# Out:
# 0.098337818094205109

# %%
np.average(ten_door_switch)
# Out:
# 0.11326687971693733
